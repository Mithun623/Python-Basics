# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")
data
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Class
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")
data
sns.relplot(x="Sepal_Length", y="Sepal_Width",data=data)

# %%
data = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")
sns.relplot(x="Sepal_Length", y="Sepal_Width",data=data, kind="line")

# %%
sns.catplot(x="Sepal_Length", y="Sepal_Width",data=data)

# %%
sns.catplot(x="Sepal_Length", y="Sepal_Width",kind="violin", data=data)

# %%
sns.catplot(x="Sepal_Length", y="Sepal_Width",kind="boxen",data=data)

# %%
from scipy import stats
import numpy as np
c=np.random.normal(loc=5,size=100,scale=2)
sns.displot(c)

# %%
data = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")
#This class maps each variable in a dataset onto a column and row in a grid of multiple axes
b=sns.PairGrid(data)
b.map(plt.scatter)

# %%
sns.set(style="darkgrid")
data = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")
b=sns.PairGrid(data)
b.map(plt.scatter)

# %%
sns.set(style="white",color_codes=True)
data = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")
sns.boxplot(x="Sepal_Length",y="Sepal_Width",data=data)
# Out:
# <AxesSubplot:xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %%
sns.set(style="white",color_codes=True)
data = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")
sns.boxplot(x="Sepal_Length",y="Sepal_Width",data=data)
sns.despine(offset=10,trim=True)

# %%
c=sns.color_palette()
sns.palplot(c)

# %%
sns.pairplot(data)
#load data on tips
tips_df = pd.read_csv("C:/Users/MyLap/Downloads/iris.csv")

# %%
sns.barplot(x='Sepal_Length',y='Sepal_Width',data=data,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %%
plt.figure(figsize=(14,9))
sns.set_style('darkgrid')
sns.boxplot(x='Sepal_Length',y='Sepal_Width',data=data)
plt.legend(loc=0)
# Out:
# No handles with labels found to put in legend.

# %%
sns.violinplot(x='Sepal_Length',y='Sepal_Width',data=data,split=True)
# Out:
# <AxesSubplot:xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %%
sns.violinplot(x='Sepal_Length',y='Sepal_Width',data=data)
sns.swarmplot(x='Sepal_Length',y='Sepal_Width',data=data,color='white')
# Out:
# C:\Users\MyLap\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\MyLap\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\MyLap\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\MyLap\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
