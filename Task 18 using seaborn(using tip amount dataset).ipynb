# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_excel("C:/Users/MyLap/Downloads/tip-amount_(2).xlsx")
data
# Out:
#    Meal  Observed total bill(xi)  Observed tip bill(yi)
# 0   1.0                     34.0                    5.0
# 1   2.0                    108.0                   17.0
# 2   3.0                     64.0                   11.0
# 3   4.0                     88.0                    8.0
# 4   5.0                     99.0                   14.0

# %%
sns.relplot(x="Observed total bill(xi)", y="Observed tip bill(yi)",data=data)

# %%
data = pd.read_excel("C:/Users/MyLap/Downloads/tip-amount_(2).xlsx")
sns.relplot(x="Observed total bill(xi)",y="Observed tip bill(yi)",data=data, kind="line")

# %%
sns.catplot(x="Observed total bill(xi)", y="Observed tip bill(yi)",data=data)

# %%
sns.catplot(x="Observed total bill(xi)", y="Observed tip bill(yi)",kind="violin", data=data)

# %%
data = pd.read_excel("C:/Users/MyLap/Downloads/tip-amount_(2).xlsx")
b=sns.PairGrid(data)
b.map(plt.scatter)

# %%
sns.set(style="darkgrid")
data = pd.read_excel("C:/Users/MyLap/Downloads/tip-amount_(2).xlsx")
b=sns.PairGrid(data)
b.map(plt.scatter)

# %%
sns.set(style="dark")
data = pd.read_excel("C:/Users/MyLap/Downloads/tip-amount_(2).xlsx")
b=sns.PairGrid(data)
b.map(plt.scatter)

# %%
sns.set(style="white",color_codes=True)
data = pd.read_excel("C:/Users/MyLap/Downloads/tip-amount_(2).xlsx")
sns.boxplot(x="Observed total bill(xi)",y="Observed tip bill(yi)",data=data)
# Out:
# <AxesSubplot:xlabel='Observed total bill(xi)', ylabel='Observed tip bill(yi)'>

# %%
sns.jointplot(x='Observed total bill(xi)', y='Observed tip bill(yi)',data=data,kind='reg')

# %%
sns.kdeplot(data['Observed total bill(xi)'])
# Out:
# <AxesSubplot:xlabel='Observed total bill(xi)', ylabel='Density'>

# %%
sns.rugplot(data['Observed total bill(xi)'])
# Out:
# <AxesSubplot:xlabel='Observed total bill(xi)'>

# %%
sns.barplot(x='Observed total bill(xi)',y='Observed tip bill(yi)',data=data,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Observed total bill(xi)', ylabel='Observed tip bill(yi)'>

# %%
plt.figure(figsize=(8,6))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='Observed total bill(xi)',y='Observed tip bill(yi)',data=data,
             palette='seismic')
plt.legend(loc=0)
# Out:
# No handles with labels found to put in legend.
