# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("C:/Users/MyLap/Downloads/housepricedata.csv")
data
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %%
sns.relplot(x="LotArea", y="TotalBsmtSF",data=data)

# %%
data = pd.read_csv("C:/Users/MyLap/Downloads/housepricedata.csv")
sns.relplot(x="TotalBsmtSF", y="LotArea",data=data, kind="line")

# %%
sns.catplot(x="LotArea", y="TotalBsmtSF",data=data)

# %%
sns.catplot(x="LotArea", y="TotalBsmtSF",kind="violin", data=data)

# %%
sns.catplot(x="LotArea", y="TotalBsmtSF",kind="boxen",data=data)

# %%
data = pd.read_csv("C:/Users/MyLap/Downloads/housepricedata.csv")
b=sns.PairGrid(data)
b.map(plt.scatter)

# %%
sns.set(style="white",color_codes=True)
data = pd.read_csv("C:/Users/MyLap/Downloads/housepricedata.csv")
sns.boxplot(x="LotArea",y="TotalBsmtSF",data=data)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='TotalBsmtSF'>

# %%
sns.jointplot(x='LotArea', y='TotalBsmtSF',data=data,kind='reg')

# %%
plt.figure(figsize=(14,9))
sns.set_style('darkgrid')
sns.boxplot(x='LotArea',y='TotalBsmtSF',data=tips_df,hue='sex')
plt.legend(loc=0)

# %%
sns.violinplot(x='LotArea',y='TotalBsmtSF',data=data,split=True)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='TotalBsmtSF'>
